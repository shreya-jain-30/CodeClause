# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression

# %%
df=pd.read_csv('sonar.csv',header=None)

# %%
df.head()
# Out:
#        0       1       2       3       4       5       6       7       8   \
# 0  0.0200  0.0371  0.0428  0.0207  0.0954  0.0986  0.1539  0.1601  0.3109
# 1  0.0453  0.0523  0.0843  0.0689  0.1183  0.2583  0.2156  0.3481  0.3337
# 2  0.0262  0.0582  0.1099  0.1083  0.0974  0.2280  0.2431  0.3771  0.5598
# 3  0.0100  0.0171  0.0623  0.0205  0.0205  0.0368  0.1098  0.1276  0.0598
# 4  0.0762  0.0666  0.0481  0.0394  0.0590  0.0649  0.1209  0.2467  0.3564
#
#        9   ...      51      52      53      54      55      56      57  \
# 0  0.2111  ...  0.0027  0.0065  0.0159  0.0072  0.0167  0.0180  0.0084
# 1  0.2872  ...  0.0084  0.0089  0.0048  0.0094  0.0191  0.0140  0.0049
# 2  0.6194  ...  0.0232  0.0166  0.0095  0.0180  0.0244  0.0316  0.0164
# 3  0.1264  ...  0.0121  0.0036  0.0150  0.0085  0.0073  0.0050  0.0044
# 4  0.4459  ...  0.0031  0.0054  0.0105  0.0110  0.0015  0.0072  0.0048
#
#        58      59  60
# 0  0.0090  0.0032   R
# 1  0.0052  0.0044   R
# 2  0.0095  0.0078   R
# ...

# %%
df.describe()
# Out:
#                0           1           2           3           4           5   \
# count  208.000000  208.000000  208.000000  208.000000  208.000000  208.000000
# mean     0.029164    0.038437    0.043832    0.053892    0.075202    0.104570
# std      0.022991    0.032960    0.038428    0.046528    0.055552    0.059105
# min      0.001500    0.000600    0.001500    0.005800    0.006700    0.010200
# 25%      0.013350    0.016450    0.018950    0.024375    0.038050    0.067025
# 50%      0.022800    0.030800    0.034300    0.044050    0.062500    0.092150
# 75%      0.035550    0.047950    0.057950    0.064500    0.100275    0.134125
# max      0.137100    0.233900    0.305900    0.426400    0.401000    0.382300
#
#                6           7           8           9   ...          50  \
# count  208.000000  208.000000  208.000000  208.000000  ...  208.000000
# mean     0.121747    0.134799    0.178003    0.208259  ...    0.016069
# ...

# %%
df.isnull().sum()
# Out:
# 0     0
# 1     0
# 2     0
# 3     0
# 4     0
#      ..
# 56    0
# 57    0
# 58    0
# 59    0
# 60    0
# Length: 61, dtype: int64

# %%
df[60].value_counts()
# Out:
# 60
# M    111
# R     97
# Name: count, dtype: int64

# %%
df.groupby(60).sum()
# Out:
#         0       1       2       3       4        5        6        7   \
# 60
# M   3.8838  5.0554  5.6299  7.1892  9.6254  12.4169  14.2478  16.6314
# R   2.1823  2.9394  3.4872  4.0204  6.0167   9.3337  11.0755  11.4068
#
#          8        9   ...      50      51      52      53      54      55  \
# 60                    ...
# M   23.6976  27.8634  ...  2.1481  1.7775  1.2924  1.3525  1.1014  0.9894
# R   13.3270  15.4545  ...  1.1942  1.0139  0.9351  0.9232  0.8310  0.7207
#
#         56      57      58      59
# 60
# M   0.8686  1.0057  0.9652  0.7692
# R   0.7580  0.6477  0.6866  0.5843
#
# [2 rows x 60 columns]

# %%
X=df.drop(columns=60)
Y=df[60]

# %%
X_Train,X_Test,Y_Train,Y_Test=train_test_split(X,Y,test_size=0.2,stratify=Y)

# %%
lr=LogisticRegression()

# %%
lr.fit(X_Train,Y_Train)
# Out:
# LogisticRegression()

# %%
y_pred=lr.predict(X_Test)

# %%
y_pred
# Out:
# array(['M', 'M', 'R', 'R', 'M', 'M', 'M', 'M', 'R', 'M', 'R', 'R', 'M',
#        'R', 'R', 'M', 'M', 'M', 'M', 'R', 'M', 'M', 'R', 'M', 'R', 'R',
#        'M', 'M', 'R', 'R', 'M', 'M', 'R', 'M', 'R', 'M', 'R', 'M', 'M',
#        'M', 'R', 'M'], dtype=object)

# %%
from sklearn.metrics import accuracy_score,precision_score,recall_score,f1_score,confusion_matrix

# %%
print("Accuracy is:",accuracy_score(y_pred,Y_Test))
print("Precision is:",precision_score(y_pred,Y_Test,pos_label='M'))
print("Recall is:",recall_score(y_pred,Y_Test,pos_label='M'))
print("f1_score is:",f1_score(y_pred,Y_Test,pos_label='M'))
print('Confusion Matrix: \n', confusion_matrix(Y_Test,y_pred))
# Out:
# Accuracy is: 0.8809523809523809
# Precision is: 0.9545454545454546
# Recall is: 0.84
# f1_score is: 0.8936170212765958
# Confusion Matrix:
#  [[21  1]
#  [ 4 16]]

# %%
ip=(0.0388,0.0324,0.0688,0.0898,0.1267,0.1515,0.2134,0.2613,0.2832,0.2718,0.3645,0.3934,0.3843,0.4677,0.5364,0.4823,0.4835,0.5862,0.7579,0.6997,0.6918,0.8633,0.9107,0.9346,0.7884,0.8585,0.9261,0.7080,0.5779,0.5215,0.4505,0.3129,0.1448,0.1046,0.1820,0.1519,0.1017,0.1438,0.1986,0.2039,0.2778,0.2879,0.1331,0.1140,0.1310,0.1433,0.0624,0.0100,0.0098,0.0131,0.0152,0.0255,0.0071,0.0263,0.0079,0.0111,0.0107,0.0068,0.0097,0.0067)
numip=np.asarray(ip)
numip_shape=numip.reshape(1,-1)

# %%
pred=lr.predict(numip_shape)
if pred[0]=='R':
    print("The object is Rock")
else:
    print("The object is Mine")
# Out:
# The object is Mine
